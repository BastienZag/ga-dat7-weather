# %% [markdown]
# # Data Science Course Week 2 - Data Visuaisation
#
# ## We will be exploring datasets with Python visualisation libraries
#
# For more information refer to the [Pandas Documentation](http://pandas.pydata.org/pandas-docs/stable/visualization.html)

# %%
# %matplotlib inline
import pandas
import matplotlib
import seaborn
import numpy as np
# Add any other library imports here

# %%
# read drinks.csv into a DataFrame called 'drinks'
drinks = pandas.read_csv('drinks.csv', index_col = 0)
drinks
# Out:
#                       beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan                       0                0              0
# Albania                          89              132             54
# Algeria                          25                0             14
# Andorra                         245              138            312
# Angola                          217               57             45
# Antigua & Barbuda               102              128             45
# Argentina                       193               25            221
# Armenia                          21              179             11
# Australia                       261               72            212
# Austria                         279               75            191
# Azerbaijan                       21               46              5
# Bahamas                         122              176             51
# Bahrain                          42               63              7
# Bangladesh                        0                0              0
# Barbados                        143              173             36
# Belarus                         142              373             42
# Belgium                         295               84            212
# Belize                          263              114              8
# Benin                            34                4             13
# Bhutan                           23                0              0
# Bolivia                         167               41              8
# Bosnia-Herzegovina               76              173              8
# Botswana                        173               35             35
# Brazil                          245              145             16
# Brunei                           31                2              1
# Bulgaria                        231              252             94
# Burkina Faso                     25                7              7
# Burundi                          88                0              0
# Cote d'Ivoire                    37                1              7
# Cabo Verde                      144               56             16
# ...                             ...              ...            ...
# Suriname                        128              178              7
# Swaziland                        90                2              2
# Sweden                          152               60            186
# Switzerland                     185              100            280
# Syria                             5               35             16
# Tajikistan                        2               15              0
# Thailand                         99              258              1
# Macedonia                       106               27             86
# Timor-Leste                       1                1              4
# Togo                             36                2             19
# Tonga                            36               21              5
# Trinidad & Tobago               197              156              7
# Tunisia                          51                3             20
# Turkey                           51               22              7
# Turkmenistan                     19               71             32
# Tuvalu                            6               41              9
# Uganda                           45                9              0
# Ukraine                         206              237             45
# United Arab Emirates             16              135              5
# United Kingdom                  219              126            195
# Tanzania                         36                6              1
# USA                             249              158             84
# Uruguay                         115               35            220
# Uzbekistan                       25              101              8
# Vanuatu                          21               18             11
# Venezuela                       333              100              3
# Vietnam                         111                2              1
# Yemen                             6                0              0
# Zambia                           32               19              4
# Zimbabwe                         64               18              4
#
#                       total_litres_of_pure_alcohol continent
# country
# Afghanistan                                    0.0        AS
# Albania                                        4.9        EU
# Algeria                                        0.7        AF
# Andorra                                       12.4        EU
# Angola                                         5.9        AF
# Antigua & Barbuda                              4.9       NaN
# Argentina                                      8.3        SA
# Armenia                                        3.8        EU
# Australia                                     10.4        OC
# Austria                                        9.7        EU
# Azerbaijan                                     1.3        EU
# Bahamas                                        6.3       NaN
# Bahrain                                        2.0        AS
# Bangladesh                                     0.0        AS
# Barbados                                       6.3       NaN
# Belarus                                       14.4        EU
# Belgium                                       10.5        EU
# Belize                                         6.8       NaN
# Benin                                          1.1        AF
# Bhutan                                         0.4        AS
# Bolivia                                        3.8        SA
# Bosnia-Herzegovina                             4.6        EU
# Botswana                                       5.4        AF
# Brazil                                         7.2        SA
# Brunei                                         0.6        AS
# Bulgaria                                      10.3        EU
# Burkina Faso                                   4.3        AF
# Burundi                                        6.3        AF
# Cote d'Ivoire                                  4.0        AF
# Cabo Verde                                     4.0        AF
# ...                                            ...       ...
# Suriname                                       5.6        SA
# Swaziland                                      4.7        AF
# Sweden                                         7.2        EU
# Switzerland                                   10.2        EU
# Syria                                          1.0        AS
# Tajikistan                                     0.3        AS
# Thailand                                       6.4        AS
# Macedonia                                      3.9        EU
# Timor-Leste                                    0.1        AS
# Togo                                           1.3        AF
# Tonga                                          1.1        OC
# Trinidad & Tobago                              6.4       NaN
# Tunisia                                        1.3        AF
# Turkey                                         1.4        AS
# Turkmenistan                                   2.2        AS
# Tuvalu                                         1.0        OC
# Uganda                                         8.3        AF
# Ukraine                                        8.9        EU
# United Arab Emirates                           2.8        AS
# United Kingdom                                10.4        EU
# Tanzania                                       5.7        AF
# USA                                            8.7       NaN
# Uruguay                                        6.6        SA
# Uzbekistan                                     2.4        AS
# Vanuatu                                        0.9        OC
# Venezuela                                      7.7        SA
# Vietnam                                        2.0        AS
# Yemen                                          0.1        AS
# Zambia                                         2.5        AF
# Zimbabwe                                       4.7        AF
#
# [193 rows x 5 columns]

# %%
# Draw a bar plot of number of countries in each continent.
# You might find .value_counts() helpful
drinks.continent.value_counts().plot.bar()

# %%
# Draw a bar plot of average number of beer servings (per adult per year) by continent
# You might find .groupby() helpful here
drinks.groupby('continent').beer_servings.mean().plot.bar()

# %%
# Draw a histogram of beer servings (shows the distribution of a numeric column)
drinks.beer_servings.hist()

# %%
# Draw a scatterplot of beer servings versus wine servings


# It's nicer if we keep the group by continent :)
drinksByContinent = drinks.groupby('continent')

drinksByContinent.beer_servings.mean().plot()
drinksByContinent.wine_servings.mean().plot()


drinks.plot.scatter('beer_servings', 'wine_servings')

# %%
# Do the same scatterplot, except colour each point by 'spirit_servings'
drinks.plot.scatter('beer_servings', 'wine_servings', c=drinks.spirit_servings, colormap=matplotlib.pyplot.cm.rainbow)

# %%
# What about if all the European countries were colored red
# You might find numpy.where useful to generate this list
colors = np.where(drinks.continent=='EU', 'r', 'b')
drinks.plot(kind='scatter', x='beer_servings', y='wine_servings', c=colors)

# %% [markdown]
# ## Seaborn

# %%
# What does a kernel density estimate of beer versus wine servings look like?
seaborn.jointplot(data=drinks, x='beer_servings', y='wine_servings', kind = 'kde')
# Out:
# /Users/Bastien/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
# Create a pairplot of all numerical columns in the dataset '
seaborn.pairplot(drinks)
